# %% [markdown]
# Projeto 2 de Teoria e Aplicação de Grafos
#
# Semestre 25.2
#
# Integrantes:
#
# Davi Galvão Guerra - 241038577
# Eric Wu Harris - 242001482
# Felipe Lauterjung Caselli - 241032401

# %%
#Importa as métricas do projeto
import re

N_PROJETOS = 50
N_ALUNOS = 200
MAX_VAGAS = 80

# %%
#Define as classes necessárias para o emparelhamento
class Projeto:
    def __init__(self, codigo, n_vagas, min_notas):
        self.codigo = codigo
        self.n_vagas = n_vagas
        self.min_notas = min_notas
        self.alunos_atribuidos = []

    def __repr__(self):
        return f"Projeto('{self.codigo}', Vagas: {self.n_vagas}, Nota mínima: {self.min_notas}, Alunos: {[aluno.codigo for aluno in self.alunos_atribuidos]})"

class Aluno:
    def __init__(self, codigo, preferencias, nota):
        self.codigo = codigo
        self.preferencias = preferencias
        self.nota = nota
        self.projeto_atribuido = None

    def __repr__(self):
        return f"Aluno('{self.codigo}', Nota: {self.nota}, Prefs: {self.preferencias}, Projeto: {self.projeto_atribuido})"

# %%
#Extrai as informações do "entradaProj2.25TAG.txt"
projetos = []
alunos = []

def extrair_e_popular_listas(nome_arquivo, lista_projetos, lista_alunos):
    padrao_projeto = re.compile(r"^\((P\d+), (\d+), (\d+)\)$")
    padrao_aluno = re.compile(r"^\((A\d+)\):\((.*?)\) \((\d+)\)$")

    try:
        with open(nome_arquivo, 'r', encoding='utf-8') as arquivo:
            for linha in arquivo:
                linha = linha.strip()

                if not linha or linha.startswith('//'):
                    continue

                match_projeto = padrao_projeto.match(linha)
                if match_projeto:
                    codigo = match_projeto.group(1)
                    n_vagas = int(match_projeto.group(2))
                    min_notas = int(match_projeto.group(3))

                    projeto = Projeto(codigo, n_vagas, min_notas)
                    lista_projetos.append(projeto)
                    continue

                match_aluno = padrao_aluno.match(linha)
                if match_aluno:
                    codigo = match_aluno.group(1)
                    projetos_str = match_aluno.group(2)
                    nota = int(match_aluno.group(3))

                    preferencias = [p.strip() for p in projetos_str.split(',')]

                    aluno = Aluno(codigo, preferencias, nota)
                    lista_alunos.append(aluno)
                    continue
    except Exception as e:
        print(e)

# %%
extrair_e_popular_listas('/entradaProj2.25TAG.txt', projetos, alunos)

# %%
#Cria o índice de preferência por projeto
preferencias_projetos = [[] for _ in range(N_PROJETOS)]
for aluno in alunos:
  for projeto_code_str in aluno.preferencias:
    projeto_idx = int(projeto_code_str[1:]) - 1
    if 0 <= projeto_idx < N_PROJETOS:
        if(projetos[projeto_idx].min_notas <= aluno.nota):
          preferencias_projetos[projeto_idx].append(aluno)
    else:
        print(f"{projeto_code_str} out of expected range for aluno {aluno.codigo}")

# %%
#Organiza a ordem de preferência dos projetos
for project_idx in range(N_PROJETOS):
    project_code = f"P{project_idx + 1}"
    preferencias_projetos[project_idx].sort(key=lambda aluno: (
        aluno.preferencias.index(project_code) if project_code in aluno.preferencias else float('inf'),
        -aluno.nota,
        aluno.codigo
    ))

# %%
#Algoritmo SPA
import copy

def SPA(initial_projetos, initial_alunos, preferencias_projetos):
    projetos_copy = copy.deepcopy(initial_projetos)
    alunos_copy = copy.deepcopy(initial_alunos)

    projetos_map = {p.codigo: p for p in projetos_copy}

    alunos_livres = [aluno for aluno in alunos_copy if aluno.preferencias]

    while alunos_livres:
        aluno = alunos_livres.pop(0)

        if not aluno.preferencias:
            continue

        projeto_codigo = aluno.preferencias.pop(0)

        projeto = projetos_map.get(projeto_codigo)

        if projeto:
            if aluno.nota >= projeto.min_notas:
                if len(projeto.alunos_atribuidos) < projeto.n_vagas:
                    projeto.alunos_atribuidos.append(aluno)
                    aluno.projeto_atribuido = projeto
                else:
                    project_idx = int(projeto.codigo[1:]) - 1

                    if not (0 <= project_idx < len(preferencias_projetos)):
                        if aluno.preferencias:
                            alunos_livres.append(aluno)
                        continue

                    project_prefs_list = preferencias_projetos[project_idx]

                    pior_aluno = None
                    pior_aluno_rank_index = -1

                    for assigned_aluno in projeto.alunos_atribuidos:
                        try:
                            rank = project_prefs_list.index(assigned_aluno)
                        except ValueError:
                            rank = float('inf')

                        if rank > pior_aluno_rank_index:
                            pior_aluno_rank_index = rank
                            pior_aluno = assigned_aluno

                    aluno_rank_index = float('inf')
                    try:
                        aluno_rank_index = project_prefs_list.index(aluno)
                    except ValueError:
                        if aluno.preferencias:
                            alunos_livres.append(aluno)
                        continue

                    if pior_aluno and aluno_rank_index < pior_aluno_rank_index:
                        projeto.alunos_atribuidos.remove(pior_aluno)
                        pior_aluno.projeto_atribuido = None
                        if pior_aluno.preferencias:
                            alunos_livres.append(pior_aluno)

                        projeto.alunos_atribuidos.append(aluno)
                        aluno.projeto_atribuido = projeto
                    else:
                        if aluno.preferencias:
                            alunos_livres.append(aluno)
            else:
                if aluno.preferencias:
                    alunos_livres.append(aluno)
        else:
            if aluno.preferencias:
                alunos_livres.append(aluno)

    return projetos_copy, alunos_copy

# %%
final_projetos_da, final_alunos_da = SPA(projetos, alunos, preferencias_projetos)

# %%
#Gera a matriz final dos emparelhamentos com as escolhas dos estudantes
import pandas as pd

matching_data = []

for aluno in final_alunos_da:
    student_code = aluno.codigo
    assigned_project_code = None
    student_rank_in_project = None
    project_rank_for_student = None

    if aluno.projeto_atribuido:
        assigned_project_code = aluno.projeto_atribuido.codigo

        project_idx = int(assigned_project_code[1:]) - 1
        if 0 <= project_idx < len(preferencias_projetos):
            try:
                temp_aluno_list_for_project_rank = [a for a in preferencias_projetos[project_idx] if a.codigo == aluno.codigo]
                if temp_aluno_list_for_project_rank:
                    student_rank_in_project = preferencias_projetos[project_idx].index(temp_aluno_list_for_project_rank[0]) + 1
                else:
                    student_rank_in_project = 'Não na Pref. do Projeto'
            except ValueError:
                student_rank_in_project = 'Não na Pref. do Projeto'
        else:
            student_rank_in_project = 'Índice de Projeto Inválido'

        original_aluno = next((a for a in alunos if a.codigo == aluno.codigo), None)
        if original_aluno and assigned_project_code in original_aluno.preferencias:
            project_rank_for_student = original_aluno.preferencias.index(assigned_project_code) + 1
        else:
            project_rank_for_student = 'Não nas Pref. do Aluno'
    else:
        assigned_project_code = 'Não Alocado'
        student_rank_in_project = None
        project_rank_for_student = None

    matching_data.append({
        'Aluno': student_code,
        'Projeto Emparelhado': assigned_project_code,
        'Rank do Aluno (pelo Projeto)': student_rank_in_project,
        'Rank do Projeto (pelo Aluno)': project_rank_for_student
    })

matching_matrix_df = pd.DataFrame(matching_data)
display(matching_matrix_df)

# %%
import copy
import re
import networkx as nx
import matplotlib.pyplot as plt
import os

# %%
# Redefine as classes novamente para garantir que estejam disponíveis dentro do novo escopo da função
class Projeto:
    def __init__(self, codigo, n_vagas, min_notas):
        self.codigo = codigo
        self.n_vagas = n_vagas
        self.min_notas = min_notas
        self.alunos_atribuidos = []

    def __repr__(self):
        return f"Projeto('{self.codigo}', Vagas: {self.n_vagas}, Nota mínima: {self.min_notas}, Alunos: {[aluno.codigo for aluno in self.alunos_atribuidos]})"

class Aluno:
    def __init__(self, codigo, preferencias, nota):
        self.codigo = codigo
        self.preferencias = preferencias 
        self.original_preferencias = list(preferencias)
        self.nota = nota
        self.projeto_atribuido = None

    def __repr__(self):
        return f"Aluno('{self.codigo}', Nota: {self.nota}, Prefs: {self.preferencias}, Projeto: {self.projeto_atribuido})"

# %%
# Função SPA com visualização do histórico
def SPA_visualize(initial_projetos_map, initial_alunos, preferencias_projetos_original):
    projetos_copy = copy.deepcopy(list(initial_projetos_map.values())) 
    alunos_copy = copy.deepcopy(initial_alunos)

    for i, aluno_orig in enumerate(initial_alunos):
        alunos_copy[i].preferencias = list(aluno_orig.preferencias)
        alunos_copy[i].original_preferencias = list(aluno_orig.preferencias)

    preferencias_projetos_viz = [[a for a in sublist] for sublist in preferencias_projetos_original]

    projetos_map = {p.codigo: p for p in projetos_copy}
    alunos_map = {a.codigo: a for a in alunos_copy}

    alunos_livres_queue = [aluno for aluno in alunos_copy if aluno.preferencias]

    history = []
    iteration = 0
    rejected_edges_set = set()

    while alunos_livres_queue:
        iteration += 1
        current_matchings = []
        for p_code, p_obj in projetos_map.items():
            for a in p_obj.alunos_atribuidos:
                current_matchings.append((a.codigo, p_obj.codigo))

        history.append({
            'iteration': iteration,
            'proposing': None,
            'matchings': list(current_matchings),
            'free_students': [a.codigo for a in alunos_livres_queue],
            'rejection': None,
            'all_rejected_edges': list(rejected_edges_set)
        })

        aluno = alunos_livres_queue.pop(0)

        if not aluno.preferencias:
            continue

        projeto_codigo = aluno.preferencias.pop(0)
        projeto = projetos_map.get(projeto_codigo)
        proposing_edge = (aluno.codigo, projeto_codigo)

        history[-1]['proposing'] = proposing_edge

        if projeto:
            if aluno.nota >= projeto.min_notas: 
                if len(projeto.alunos_atribuidos) < projeto.n_vagas:
                    projeto.alunos_atribuidos.append(aluno)
                    aluno.projeto_atribuido = projeto
                else:
                    project_idx = int(projeto.codigo[1:]) - 1 

                    if not (0 <= project_idx < len(preferencias_projetos_viz)):
                        if aluno.preferencias:
                            alunos_livres_queue.append(aluno)
                        rejected_edges_set.add(proposing_edge)
                        continue

                    project_prefs_list = preferencias_projetos_viz[project_idx]

                    pior_aluno = None
                    pior_aluno_rank = -1

                    assigned_alunos_codes = {a.codigo for a in projeto.alunos_atribuidos}

                    for pref_aluno_obj in project_prefs_list:
                        if pref_aluno_obj.codigo in assigned_alunos_codes:
                            try:
                                current_rank = project_prefs_list.index(pref_aluno_obj)
                            except ValueError:
                                current_rank = float('inf')
                            if pior_aluno is None or current_rank > pior_aluno_rank:
                                pior_aluno_rank = current_rank
                                pior_aluno = pref_aluno_obj

                    aluno_rank = float('inf')
                    for pref_aluno_obj in project_prefs_list:
                        if pref_aluno_obj.codigo == aluno.codigo:
                            aluno_rank = project_prefs_list.index(pref_aluno_obj)
                            break

                    if pior_aluno and aluno_rank < pior_aluno_rank:
                        projeto.alunos_atribuidos.remove(alunos_map[pior_aluno.codigo])
                        alunos_map[pior_aluno.codigo].projeto_atribuido = None

                        if alunos_map[pior_aluno.codigo].preferencias:
                            alunos_livres_queue.append(alunos_map[pior_aluno.codigo])

                        rejection_edge = (alunos_map[pior_aluno.codigo].codigo, projeto_codigo)
                        history[-1]['rejection'] = rejection_edge
                        rejected_edges_set.add(rejection_edge)

                        projeto.alunos_atribuidos.append(aluno)
                        aluno.projeto_atribuido = projeto
                    else:
                        rejection_edge = proposing_edge
                        history[-1]['rejection'] = rejection_edge
                        rejected_edges_set.add(rejection_edge)
                        if aluno.preferencias:
                            alunos_livres_queue.append(aluno)
            else:
                rejection_edge = proposing_edge
                history[-1]['rejection'] = rejection_edge
                rejected_edges_set.add(rejection_edge) 
                if aluno.preferencias:
                    alunos_livres_queue.append(aluno)
        else:
            rejection_edge = proposing_edge
            history[-1]['rejection'] = rejection_edge
            rejected_edges_set.add(rejection_edge)
            if aluno.preferencias:
                alunos_livres_queue.append(aluno)

    iteration += 1 #
    final_matchings = []
    for p_code, p_obj in projetos_map.items():
        for a in p_obj.alunos_atribuidos:
            final_matchings.append((a.codigo, p_obj.codigo))

    history.append({
        'iteration': iteration,
        'proposing': None,
        'matchings': final_matchings,
        'free_students': [a.codigo for a in alunos_copy if a.projeto_atribuido is None],
        'rejection': None,
        'all_rejected_edges': list(rejected_edges_set)
    })

    return projetos_copy, alunos_copy, history

# %%
# Função para desenhar o grafo bipartido em cada iteração
def draw_bipartite_graph(iteration, proposing_edge, current_matchings, rejection_edge, all_rejected_edges_for_frame, student_nodes, project_nodes, pos, output_directory):
    os.makedirs(output_directory, exist_ok=True)

    G = nx.Graph()
    G.add_nodes_from(student_nodes, bipartite=0)
    G.add_nodes_from(project_nodes, bipartite=1)

    edge_info = {}

    for student, project in current_matchings:
        edge_info[(student, project)] = 'blue'

    if proposing_edge:
        edge_info[proposing_edge] = 'green'

    if rejection_edge:
        edge_info[rejection_edge] = 'red'

    edges = []
    edge_colors = []
    for edge, color in edge_info.items():
        edges.append(edge)
        edge_colors.append(color)

    fig, ax = plt.subplots(figsize=(15, 8))

    nx.draw_networkx_nodes(G, pos, nodelist=student_nodes, node_color='lightcoral', node_shape='o', label='Alunos')
    nx.draw_networkx_nodes(G, pos, nodelist=project_nodes, node_color='lightskyblue', node_shape='s', label='Projetos')

    valid_edges = []
    valid_edge_colors = []
    for i, (u, v) in enumerate(edges):
        if u in pos and v in pos:
            valid_edges.append((u, v))
            valid_edge_colors.append(edge_colors[i])

    nx.draw_networkx_edges(G, pos, edgelist=valid_edges, edge_color=valid_edge_colors, width=2.5)

    nx.draw_networkx_labels(G, pos, font_size=8)

    action_text = ""
    action_color = 'black'

    if proposing_edge:
        aluno, projeto = proposing_edge
        action_text = f"PROPOSTA: {aluno} tenta emparelhar com {projeto}."
        action_color = 'green'

    if rejection_edge:
        aluno_rejeitado, projeto_rejeitou = rejection_edge
        if proposing_edge == rejection_edge:
            action_text = f"REJEIÇÃO: {aluno_rejeitado} é rejeitado por {projeto_rejeitou}."
            action_color = 'red'
        else:
            aluno_proponente = proposing_edge[0] if proposing_edge else '?'
            action_text = f"REJEIÇÃO: {aluno_rejeitado} é substituído e rejeitado por {projeto_rejeitou} (em favor de {aluno_proponente})."
            action_color = 'red'

    ax.set_title(f'Algoritmo Gale-Shapley - Iteração {iteration}', fontsize=16)

    if action_text:
        plt.figtext(0.5, 0.06, action_text, ha='center', fontsize=12, color=action_color)

    ax.set_title(f'Gale-Shapley Algorithm - Iteration {iteration}', fontsize=16)

    blue_line = plt.Line2D([0], [0], color='blue', lw=2.5, label='Emparelhamento Temporário')
    green_line = plt.Line2D([0], [0], color='green', lw=2.5, label='Proposta Ativa')
    red_line = plt.Line2D([0], [0], color='red', lw=2.5, label='Rejeição')

    ax.legend(handles=[green_line, blue_line, red_line], loc='upper left', bbox_to_anchor=(1,1))

    ax.set_xticks([])
    ax.set_yticks([])

    filename = os.path.join(output_directory, f'iteration_{iteration:04d}.png')
    plt.savefig(filename, bbox_inches='tight', dpi=100)
    plt.close(fig)

    print(f"Iteration {iteration:04d} visualization saved to {filename}")

# %%
# Função para extrair dados do arquivo e popular as listas de projetos e alunos
def extrair_e_popular_listas(nome_arquivo, projetos_dict, lista_alunos):
    padrao_projeto = re.compile(r"^\((P\d+), (\d+), (\d+)\)$")
    padrao_aluno = re.compile(r"^\((A\d+)\):\((.*?)\) \((\d+)\)$")

    try:
        with open(nome_arquivo, 'r', encoding='utf-8') as arquivo:
            for linha in arquivo:
                linha = linha.strip()

                if not linha or linha.startswith('//'):
                    continue

                match_projeto = padrao_projeto.match(linha)
                if match_projeto:
                    codigo = match_projeto.group(1)
                    n_vagas = int(match_projeto.group(2))
                    min_notas = int(match_projeto.group(3))

                    projetos_dict[codigo] = Projeto(codigo, n_vagas, min_notas)
                    continue

                match_aluno = padrao_aluno.match(linha)
                if match_aluno:
                    codigo = match_aluno.group(1)
                    projetos_str = match_aluno.group(2)
                    nota = int(match_aluno.group(3))

                    preferencias = [p.strip() for p in projetos_str.split(',')]

                    aluno = Aluno(codigo, preferencias, nota)
                    lista_alunos.append(aluno)
                    continue
    except Exception as e:
        print(e)

# %%
projetos_map = {}
alunos = []

extrair_e_popular_listas('/entradaProj2.25TAG.txt', projetos_map, alunos)

max_project_number = 0
for p_code in projetos_map.keys():
    max_project_number = max(max_project_number, int(p_code[1:]))

for aluno in alunos:
    for pref_code in aluno.preferencias:
        if pref_code.startswith('P') and len(pref_code) > 1 and pref_code[1:].isdigit():
            max_project_number = max(max_project_number, int(pref_code[1:]))

N_PROJETOS = max_project_number

N_ALUNOS = len(alunos)

preferencias_projetos = [[] for _ in range(N_PROJETOS)]
for aluno in alunos:
  for project_code_str in aluno.preferencias:
    project_idx = int(project_code_str[1:]) - 1
    if 0 <= project_idx < N_PROJETOS and project_code_str in projetos_map:
        project_obj = projetos_map[project_code_str]
        if(project_obj.min_notas <= aluno.nota):
          preferencias_projetos[project_idx].append(aluno)

for project_idx in range(N_PROJETOS):
    project_code = f"P{project_idx + 1}"
    if project_code in projetos_map:
        preferencias_projetos[project_idx].sort(key=lambda aluno_obj: (
            aluno_obj.preferencias.index(project_code) if project_code in aluno_obj.preferencias else float('inf'),
            -aluno_obj.nota,
            aluno_obj.codigo
        ))

student_nodes = [f'A{i+1}' for i in range(N_ALUNOS)]
project_nodes = [f'P{i+1}' for i in range(N_PROJETOS)]

pos = {}

student_spacing = 5
total_student_width = (len(student_nodes) - 1) * student_spacing
student_offset_x = -total_student_width / 2

for i, student in enumerate(student_nodes):
    pos[student] = (student_offset_x + i * student_spacing, 1)

project_spacing = 20
total_project_width = (len(project_nodes) - 1) * project_spacing
project_offset_x = -total_project_width / 2

for i, project in enumerate(project_nodes):
    pos[project] = (project_offset_x + i * project_spacing, 0)


_, _, history = SPA_visualize(projetos_map, alunos, preferencias_projetos)

output_directory = 'gale_shapley_frames_new_layout'


num_frames_to_generate = None

if num_frames_to_generate is None:
    frames_to_process = history
else:
    frames_to_process = history[:num_frames_to_generate]

print(f"Generating {len(frames_to_process)} visualization frames with new layout...")

for i, entry in enumerate(frames_to_process):
    current_iteration = entry['iteration']
    proposing_edge = entry['proposing']
    current_matchings = entry['matchings']
    rejection_edge = entry['rejection']
    all_rejected_edges = entry['all_rejected_edges'] 

    draw_bipartite_graph(current_iteration, proposing_edge, current_matchings, rejection_edge, all_rejected_edges, student_nodes, project_nodes, pos, output_directory)
# Out:
# Generating 503 visualization frames with new layout...
# Iteration 0001 visualization saved to gale_shapley_frames_new_layout/iteration_0001.png
# Iteration 0002 visualization saved to gale_shapley_frames_new_layout/iteration_0002.png
# Iteration 0003 visualization saved to gale_shapley_frames_new_layout/iteration_0003.png
# Iteration 0004 visualization saved to gale_shapley_frames_new_layout/iteration_0004.png
# Iteration 0005 visualization saved to gale_shapley_frames_new_layout/iteration_0005.png
# Iteration 0006 visualization saved to gale_shapley_frames_new_layout/iteration_0006.png
# Iteration 0007 visualization saved to gale_shapley_frames_new_layout/iteration_0007.png
# Iteration 0008 visualization saved to gale_shapley_frames_new_layout/iteration_0008.png
# Iteration 0009 visualization saved to gale_shapley_frames_new_layout/iteration_0009.png
# Iteration 0010 visualization saved to gale_shapley_frames_new_layout/iteration_0010.png
# Iteration 0011 visualization saved to gale_shapley_frames_new_layout/iteration_0011.png
# Iteration 0012 visualization saved to gale_shapley_frames_new_layout/iteration_0012.png
# Iteration 0013 visualization saved to gale_shapley_frames_new_layout/iteration_0013.png
# Iteration 0014 visualization saved to gale_shapley_frames_new_layout/iteration_0014.png
# Iteration 0015 visualization saved to gale_shapley_frames_new_layout/iteration_0015.png
# Iteration 0016 visualization saved to gale_shapley_frames_new_layout/iteration_0016.png
# Iteration 0017 visualization saved to gale_shapley_frames_new_layout/iteration_0017.png
# Iteration 0018 visualization saved to gale_shapley_frames_new_layout/iteration_0018.png
# Iteration 0019 visualization saved to gale_shapley_frames_new_layout/iteration_0019.png
# Iteration 0020 visualization saved to gale_shapley_frames_new_layout/iteration_0020.png
# Iteration 0021 visualization saved to gale_shapley_frames_new_layout/iteration_0021.png
# Iteration 0022 visualization saved to gale_shapley_frames_new_layout/iteration_0022.png
# Iteration 0023 visualization saved to gale_shapley_frames_new_layout/iteration_0023.png
# Iteration 0024 visualization saved to gale_shapley_frames_new_layout/iteration_0024.png
# Iteration 0025 visualization saved to gale_shapley_frames_new_layout/iteration_0025.png
# Iteration 0026 visualization saved to gale_shapley_frames_new_layout/iteration_0026.png
# Iteration 0027 visualization saved to gale_shapley_frames_new_layout/iteration_0027.png
# Iteration 0028 visualization saved to gale_shapley_frames_new_layout/iteration_0028.png
# Iteration 0029 visualization saved to gale_shapley_frames_new_layout/iteration_0029.png
# Iteration 0030 visualization saved to gale_shapley_frames_new_layout/iteration_0030.png
# Iteration 0031 visualization saved to gale_shapley_frames_new_layout/iteration_0031.png
# Iteration 0032 visualization saved to gale_shapley_frames_new_layout/iteration_0032.png
# Iteration 0033 visualization saved to gale_shapley_frames_new_layout/iteration_0033.png
# Iteration 0034 visualization saved to gale_shapley_frames_new_layout/iteration_0034.png
# Iteration 0035 visualization saved to gale_shapley_frames_new_layout/iteration_0035.png
# Iteration 0036 visualization saved to gale_shapley_frames_new_layout/iteration_0036.png
# Iteration 0037 visualization saved to gale_shapley_frames_new_layout/iteration_0037.png
# Iteration 0038 visualization saved to gale_shapley_frames_new_layout/iteration_0038.png
# Iteration 0039 visualization saved to gale_shapley_frames_new_layout/iteration_0039.png
# Iteration 0040 visualization saved to gale_shapley_frames_new_layout/iteration_0040.png
# Iteration 0041 visualization saved to gale_shapley_frames_new_layout/iteration_0041.png
# Iteration 0042 visualization saved to gale_shapley_frames_new_layout/iteration_0042.png
# Iteration 0043 visualization saved to gale_shapley_frames_new_layout/iteration_0043.png
# Iteration 0044 visualization saved to gale_shapley_frames_new_layout/iteration_0044.png
# Iteration 0045 visualization saved to gale_shapley_frames_new_layout/iteration_0045.png
# Iteration 0046 visualization saved to gale_shapley_frames_new_layout/iteration_0046.png
# Iteration 0047 visualization saved to gale_shapley_frames_new_layout/iteration_0047.png
# Iteration 0048 visualization saved to gale_shapley_frames_new_layout/iteration_0048.png
# Iteration 0049 visualization saved to gale_shapley_frames_new_layout/iteration_0049.png
# Iteration 0050 visualization saved to gale_shapley_frames_new_layout/iteration_0050.png
# Iteration 0051 visualization saved to gale_shapley_frames_new_layout/iteration_0051.png
# Iteration 0052 visualization saved to gale_shapley_frames_new_layout/iteration_0052.png
# Iteration 0053 visualization saved to gale_shapley_frames_new_layout/iteration_0053.png
# Iteration 0054 visualization saved to gale_shapley_frames_new_layout/iteration_0054.png
# Iteration 0055 visualization saved to gale_shapley_frames_new_layout/iteration_0055.png
# Iteration 0056 visualization saved to gale_shapley_frames_new_layout/iteration_0056.png
# Iteration 0057 visualization saved to gale_shapley_frames_new_layout/iteration_0057.png
# Iteration 0058 visualization saved to gale_shapley_frames_new_layout/iteration_0058.png
# Iteration 0059 visualization saved to gale_shapley_frames_new_layout/iteration_0059.png
# Iteration 0060 visualization saved to gale_shapley_frames_new_layout/iteration_0060.png
# Iteration 0061 visualization saved to gale_shapley_frames_new_layout/iteration_0061.png
# Iteration 0062 visualization saved to gale_shapley_frames_new_layout/iteration_0062.png
# Iteration 0063 visualization saved to gale_shapley_frames_new_layout/iteration_0063.png
# Iteration 0064 visualization saved to gale_shapley_frames_new_layout/iteration_0064.png
# Iteration 0065 visualization saved to gale_shapley_frames_new_layout/iteration_0065.png
# Iteration 0066 visualization saved to gale_shapley_frames_new_layout/iteration_0066.png
# Iteration 0067 visualization saved to gale_shapley_frames_new_layout/iteration_0067.png
# Iteration 0068 visualization saved to gale_shapley_frames_new_layout/iteration_0068.png
# Iteration 0069 visualization saved to gale_shapley_frames_new_layout/iteration_0069.png
# Iteration 0070 visualization saved to gale_shapley_frames_new_layout/iteration_0070.png
# Iteration 0071 visualization saved to gale_shapley_frames_new_layout/iteration_0071.png
# Iteration 0072 visualization saved to gale_shapley_frames_new_layout/iteration_0072.png
# Iteration 0073 visualization saved to gale_shapley_frames_new_layout/iteration_0073.png
# Iteration 0074 visualization saved to gale_shapley_frames_new_layout/iteration_0074.png
# Iteration 0075 visualization saved to gale_shapley_frames_new_layout/iteration_0075.png
# Iteration 0076 visualization saved to gale_shapley_frames_new_layout/iteration_0076.png
# Iteration 0077 visualization saved to gale_shapley_frames_new_layout/iteration_0077.png
# Iteration 0078 visualization saved to gale_shapley_frames_new_layout/iteration_0078.png
# Iteration 0079 visualization saved to gale_shapley_frames_new_layout/iteration_0079.png
# Iteration 0080 visualization saved to gale_shapley_frames_new_layout/iteration_0080.png
# Iteration 0081 visualization saved to gale_shapley_frames_new_layout/iteration_0081.png
# Iteration 0082 visualization saved to gale_shapley_frames_new_layout/iteration_0082.png
# Iteration 0083 visualization saved to gale_shapley_frames_new_layout/iteration_0083.png
# Iteration 0084 visualization saved to gale_shapley_frames_new_layout/iteration_0084.png
# Iteration 0085 visualization saved to gale_shapley_frames_new_layout/iteration_0085.png
# Iteration 0086 visualization saved to gale_shapley_frames_new_layout/iteration_0086.png
# Iteration 0087 visualization saved to gale_shapley_frames_new_layout/iteration_0087.png
# Iteration 0088 visualization saved to gale_shapley_frames_new_layout/iteration_0088.png
# Iteration 0089 visualization saved to gale_shapley_frames_new_layout/iteration_0089.png
# Iteration 0090 visualization saved to gale_shapley_frames_new_layout/iteration_0090.png
# Iteration 0091 visualization saved to gale_shapley_frames_new_layout/iteration_0091.png
# Iteration 0092 visualization saved to gale_shapley_frames_new_layout/iteration_0092.png
# Iteration 0093 visualization saved to gale_shapley_frames_new_layout/iteration_0093.png
# Iteration 0094 visualization saved to gale_shapley_frames_new_layout/iteration_0094.png
# Iteration 0095 visualization saved to gale_shapley_frames_new_layout/iteration_0095.png
# Iteration 0096 visualization saved to gale_shapley_frames_new_layout/iteration_0096.png
# Iteration 0097 visualization saved to gale_shapley_frames_new_layout/iteration_0097.png
# Iteration 0098 visualization saved to gale_shapley_frames_new_layout/iteration_0098.png
# Iteration 0099 visualization saved to gale_shapley_frames_new_layout/iteration_0099.png
# Iteration 0100 visualization saved to gale_shapley_frames_new_layout/iteration_0100.png
# Iteration 0101 visualization saved to gale_shapley_frames_new_layout/iteration_0101.png
# Iteration 0102 visualization saved to gale_shapley_frames_new_layout/iteration_0102.png
# Iteration 0103 visualization saved to gale_shapley_frames_new_layout/iteration_0103.png
# Iteration 0104 visualization saved to gale_shapley_frames_new_layout/iteration_0104.png
# Iteration 0105 visualization saved to gale_shapley_frames_new_layout/iteration_0105.png
# Iteration 0106 visualization saved to gale_shapley_frames_new_layout/iteration_0106.png
# Iteration 0107 visualization saved to gale_shapley_frames_new_layout/iteration_0107.png
# Iteration 0108 visualization saved to gale_shapley_frames_new_layout/iteration_0108.png
# Iteration 0109 visualization saved to gale_shapley_frames_new_layout/iteration_0109.png
# Iteration 0110 visualization saved to gale_shapley_frames_new_layout/iteration_0110.png
# Iteration 0111 visualization saved to gale_shapley_frames_new_layout/iteration_0111.png
# Iteration 0112 visualization saved to gale_shapley_frames_new_layout/iteration_0112.png
# Iteration 0113 visualization saved to gale_shapley_frames_new_layout/iteration_0113.png
# Iteration 0114 visualization saved to gale_shapley_frames_new_layout/iteration_0114.png
# Iteration 0115 visualization saved to gale_shapley_frames_new_layout/iteration_0115.png
# Iteration 0116 visualization saved to gale_shapley_frames_new_layout/iteration_0116.png
# Iteration 0117 visualization saved to gale_shapley_frames_new_layout/iteration_0117.png
# Iteration 0118 visualization saved to gale_shapley_frames_new_layout/iteration_0118.png
# Iteration 0119 visualization saved to gale_shapley_frames_new_layout/iteration_0119.png
# Iteration 0120 visualization saved to gale_shapley_frames_new_layout/iteration_0120.png
# Iteration 0121 visualization saved to gale_shapley_frames_new_layout/iteration_0121.png
# Iteration 0122 visualization saved to gale_shapley_frames_new_layout/iteration_0122.png
# Iteration 0123 visualization saved to gale_shapley_frames_new_layout/iteration_0123.png
# Iteration 0124 visualization saved to gale_shapley_frames_new_layout/iteration_0124.png
# Iteration 0125 visualization saved to gale_shapley_frames_new_layout/iteration_0125.png
# Iteration 0126 visualization saved to gale_shapley_frames_new_layout/iteration_0126.png
# Iteration 0127 visualization saved to gale_shapley_frames_new_layout/iteration_0127.png
# Iteration 0128 visualization saved to gale_shapley_frames_new_layout/iteration_0128.png
# Iteration 0129 visualization saved to gale_shapley_frames_new_layout/iteration_0129.png
# Iteration 0130 visualization saved to gale_shapley_frames_new_layout/iteration_0130.png
# Iteration 0131 visualization saved to gale_shapley_frames_new_layout/iteration_0131.png
# Iteration 0132 visualization saved to gale_shapley_frames_new_layout/iteration_0132.png
# Iteration 0133 visualization saved to gale_shapley_frames_new_layout/iteration_0133.png
# Iteration 0134 visualization saved to gale_shapley_frames_new_layout/iteration_0134.png
# Iteration 0135 visualization saved to gale_shapley_frames_new_layout/iteration_0135.png
# Iteration 0136 visualization saved to gale_shapley_frames_new_layout/iteration_0136.png
# Iteration 0137 visualization saved to gale_shapley_frames_new_layout/iteration_0137.png
# Iteration 0138 visualization saved to gale_shapley_frames_new_layout/iteration_0138.png
# Iteration 0139 visualization saved to gale_shapley_frames_new_layout/iteration_0139.png
# Iteration 0140 visualization saved to gale_shapley_frames_new_layout/iteration_0140.png
# Iteration 0141 visualization saved to gale_shapley_frames_new_layout/iteration_0141.png
# Iteration 0142 visualization saved to gale_shapley_frames_new_layout/iteration_0142.png
# Iteration 0143 visualization saved to gale_shapley_frames_new_layout/iteration_0143.png
# Iteration 0144 visualization saved to gale_shapley_frames_new_layout/iteration_0144.png
# Iteration 0145 visualization saved to gale_shapley_frames_new_layout/iteration_0145.png
# Iteration 0146 visualization saved to gale_shapley_frames_new_layout/iteration_0146.png
# Iteration 0147 visualization saved to gale_shapley_frames_new_layout/iteration_0147.png
# Iteration 0148 visualization saved to gale_shapley_frames_new_layout/iteration_0148.png
# Iteration 0149 visualization saved to gale_shapley_frames_new_layout/iteration_0149.png
# Iteration 0150 visualization saved to gale_shapley_frames_new_layout/iteration_0150.png
# Iteration 0151 visualization saved to gale_shapley_frames_new_layout/iteration_0151.png
# Iteration 0152 visualization saved to gale_shapley_frames_new_layout/iteration_0152.png
# Iteration 0153 visualization saved to gale_shapley_frames_new_layout/iteration_0153.png
# Iteration 0154 visualization saved to gale_shapley_frames_new_layout/iteration_0154.png
# Iteration 0155 visualization saved to gale_shapley_frames_new_layout/iteration_0155.png
# Iteration 0156 visualization saved to gale_shapley_frames_new_layout/iteration_0156.png
# Iteration 0157 visualization saved to gale_shapley_frames_new_layout/iteration_0157.png
# Iteration 0158 visualization saved to gale_shapley_frames_new_layout/iteration_0158.png
# Iteration 0159 visualization saved to gale_shapley_frames_new_layout/iteration_0159.png
# Iteration 0160 visualization saved to gale_shapley_frames_new_layout/iteration_0160.png
# Iteration 0161 visualization saved to gale_shapley_frames_new_layout/iteration_0161.png
# Iteration 0162 visualization saved to gale_shapley_frames_new_layout/iteration_0162.png
# Iteration 0163 visualization saved to gale_shapley_frames_new_layout/iteration_0163.png
# Iteration 0164 visualization saved to gale_shapley_frames_new_layout/iteration_0164.png
# Iteration 0165 visualization saved to gale_shapley_frames_new_layout/iteration_0165.png
# Iteration 0166 visualization saved to gale_shapley_frames_new_layout/iteration_0166.png
# Iteration 0167 visualization saved to gale_shapley_frames_new_layout/iteration_0167.png
# Iteration 0168 visualization saved to gale_shapley_frames_new_layout/iteration_0168.png
# Iteration 0169 visualization saved to gale_shapley_frames_new_layout/iteration_0169.png
# Iteration 0170 visualization saved to gale_shapley_frames_new_layout/iteration_0170.png
# Iteration 0171 visualization saved to gale_shapley_frames_new_layout/iteration_0171.png
# Iteration 0172 visualization saved to gale_shapley_frames_new_layout/iteration_0172.png
# Iteration 0173 visualization saved to gale_shapley_frames_new_layout/iteration_0173.png
# Iteration 0174 visualization saved to gale_shapley_frames_new_layout/iteration_0174.png
# Iteration 0175 visualization saved to gale_shapley_frames_new_layout/iteration_0175.png
# Iteration 0176 visualization saved to gale_shapley_frames_new_layout/iteration_0176.png
# Iteration 0177 visualization saved to gale_shapley_frames_new_layout/iteration_0177.png
# Iteration 0178 visualization saved to gale_shapley_frames_new_layout/iteration_0178.png
# Iteration 0179 visualization saved to gale_shapley_frames_new_layout/iteration_0179.png
# Iteration 0180 visualization saved to gale_shapley_frames_new_layout/iteration_0180.png
# Iteration 0181 visualization saved to gale_shapley_frames_new_layout/iteration_0181.png
# Iteration 0182 visualization saved to gale_shapley_frames_new_layout/iteration_0182.png
# Iteration 0183 visualization saved to gale_shapley_frames_new_layout/iteration_0183.png
# Iteration 0184 visualization saved to gale_shapley_frames_new_layout/iteration_0184.png
# Iteration 0185 visualization saved to gale_shapley_frames_new_layout/iteration_0185.png
# Iteration 0186 visualization saved to gale_shapley_frames_new_layout/iteration_0186.png
# Iteration 0187 visualization saved to gale_shapley_frames_new_layout/iteration_0187.png
# Iteration 0188 visualization saved to gale_shapley_frames_new_layout/iteration_0188.png
# Iteration 0189 visualization saved to gale_shapley_frames_new_layout/iteration_0189.png
# Iteration 0190 visualization saved to gale_shapley_frames_new_layout/iteration_0190.png
# Iteration 0191 visualization saved to gale_shapley_frames_new_layout/iteration_0191.png
# Iteration 0192 visualization saved to gale_shapley_frames_new_layout/iteration_0192.png
# Iteration 0193 visualization saved to gale_shapley_frames_new_layout/iteration_0193.png
# Iteration 0194 visualization saved to gale_shapley_frames_new_layout/iteration_0194.png
# Iteration 0195 visualization saved to gale_shapley_frames_new_layout/iteration_0195.png
# Iteration 0196 visualization saved to gale_shapley_frames_new_layout/iteration_0196.png
# Iteration 0197 visualization saved to gale_shapley_frames_new_layout/iteration_0197.png
# Iteration 0198 visualization saved to gale_shapley_frames_new_layout/iteration_0198.png
# Iteration 0199 visualization saved to gale_shapley_frames_new_layout/iteration_0199.png
# Iteration 0200 visualization saved to gale_shapley_frames_new_layout/iteration_0200.png
# Iteration 0201 visualization saved to gale_shapley_frames_new_layout/iteration_0201.png
# Iteration 0202 visualization saved to gale_shapley_frames_new_layout/iteration_0202.png
# Iteration 0203 visualization saved to gale_shapley_frames_new_layout/iteration_0203.png
# Iteration 0204 visualization saved to gale_shapley_frames_new_layout/iteration_0204.png
# Iteration 0205 visualization saved to gale_shapley_frames_new_layout/iteration_0205.png
# Iteration 0206 visualization saved to gale_shapley_frames_new_layout/iteration_0206.png
# Iteration 0207 visualization saved to gale_shapley_frames_new_layout/iteration_0207.png
# Iteration 0208 visualization saved to gale_shapley_frames_new_layout/iteration_0208.png
# Iteration 0209 visualization saved to gale_shapley_frames_new_layout/iteration_0209.png
# Iteration 0210 visualization saved to gale_shapley_frames_new_layout/iteration_0210.png
# Iteration 0211 visualization saved to gale_shapley_frames_new_layout/iteration_0211.png
# Iteration 0212 visualization saved to gale_shapley_frames_new_layout/iteration_0212.png
# Iteration 0213 visualization saved to gale_shapley_frames_new_layout/iteration_0213.png
# Iteration 0214 visualization saved to gale_shapley_frames_new_layout/iteration_0214.png
# Iteration 0215 visualization saved to gale_shapley_frames_new_layout/iteration_0215.png
# Iteration 0216 visualization saved to gale_shapley_frames_new_layout/iteration_0216.png
# Iteration 0217 visualization saved to gale_shapley_frames_new_layout/iteration_0217.png
# Iteration 0218 visualization saved to gale_shapley_frames_new_layout/iteration_0218.png
# Iteration 0219 visualization saved to gale_shapley_frames_new_layout/iteration_0219.png
# Iteration 0220 visualization saved to gale_shapley_frames_new_layout/iteration_0220.png
# Iteration 0221 visualization saved to gale_shapley_frames_new_layout/iteration_0221.png
# Iteration 0222 visualization saved to gale_shapley_frames_new_layout/iteration_0222.png
# Iteration 0223 visualization saved to gale_shapley_frames_new_layout/iteration_0223.png
# Iteration 0224 visualization saved to gale_shapley_frames_new_layout/iteration_0224.png
# Iteration 0225 visualization saved to gale_shapley_frames_new_layout/iteration_0225.png
# Iteration 0226 visualization saved to gale_shapley_frames_new_layout/iteration_0226.png
# Iteration 0227 visualization saved to gale_shapley_frames_new_layout/iteration_0227.png
# Iteration 0228 visualization saved to gale_shapley_frames_new_layout/iteration_0228.png
# Iteration 0229 visualization saved to gale_shapley_frames_new_layout/iteration_0229.png
# Iteration 0230 visualization saved to gale_shapley_frames_new_layout/iteration_0230.png
# Iteration 0231 visualization saved to gale_shapley_frames_new_layout/iteration_0231.png
# Iteration 0232 visualization saved to gale_shapley_frames_new_layout/iteration_0232.png
# Iteration 0233 visualization saved to gale_shapley_frames_new_layout/iteration_0233.png
# Iteration 0234 visualization saved to gale_shapley_frames_new_layout/iteration_0234.png
# Iteration 0235 visualization saved to gale_shapley_frames_new_layout/iteration_0235.png
# Iteration 0236 visualization saved to gale_shapley_frames_new_layout/iteration_0236.png
# Iteration 0237 visualization saved to gale_shapley_frames_new_layout/iteration_0237.png
# Iteration 0238 visualization saved to gale_shapley_frames_new_layout/iteration_0238.png
# Iteration 0239 visualization saved to gale_shapley_frames_new_layout/iteration_0239.png
# Iteration 0240 visualization saved to gale_shapley_frames_new_layout/iteration_0240.png
# Iteration 0241 visualization saved to gale_shapley_frames_new_layout/iteration_0241.png
# Iteration 0242 visualization saved to gale_shapley_frames_new_layout/iteration_0242.png
# Iteration 0243 visualization saved to gale_shapley_frames_new_layout/iteration_0243.png
# Iteration 0244 visualization saved to gale_shapley_frames_new_layout/iteration_0244.png
# Iteration 0245 visualization saved to gale_shapley_frames_new_layout/iteration_0245.png
# Iteration 0246 visualization saved to gale_shapley_frames_new_layout/iteration_0246.png
# Iteration 0247 visualization saved to gale_shapley_frames_new_layout/iteration_0247.png
# Iteration 0248 visualization saved to gale_shapley_frames_new_layout/iteration_0248.png
# Iteration 0249 visualization saved to gale_shapley_frames_new_layout/iteration_0249.png
# Iteration 0250 visualization saved to gale_shapley_frames_new_layout/iteration_0250.png
# Iteration 0251 visualization saved to gale_shapley_frames_new_layout/iteration_0251.png
# Iteration 0252 visualization saved to gale_shapley_frames_new_layout/iteration_0252.png
# Iteration 0253 visualization saved to gale_shapley_frames_new_layout/iteration_0253.png
# Iteration 0254 visualization saved to gale_shapley_frames_new_layout/iteration_0254.png
# Iteration 0255 visualization saved to gale_shapley_frames_new_layout/iteration_0255.png
# Iteration 0256 visualization saved to gale_shapley_frames_new_layout/iteration_0256.png
# Iteration 0257 visualization saved to gale_shapley_frames_new_layout/iteration_0257.png
# Iteration 0258 visualization saved to gale_shapley_frames_new_layout/iteration_0258.png
# Iteration 0259 visualization saved to gale_shapley_frames_new_layout/iteration_0259.png
# Iteration 0260 visualization saved to gale_shapley_frames_new_layout/iteration_0260.png
# Iteration 0261 visualization saved to gale_shapley_frames_new_layout/iteration_0261.png
# Iteration 0262 visualization saved to gale_shapley_frames_new_layout/iteration_0262.png
# Iteration 0263 visualization saved to gale_shapley_frames_new_layout/iteration_0263.png
# Iteration 0264 visualization saved to gale_shapley_frames_new_layout/iteration_0264.png
# Iteration 0265 visualization saved to gale_shapley_frames_new_layout/iteration_0265.png
# Iteration 0266 visualization saved to gale_shapley_frames_new_layout/iteration_0266.png
# Iteration 0267 visualization saved to gale_shapley_frames_new_layout/iteration_0267.png
# Iteration 0268 visualization saved to gale_shapley_frames_new_layout/iteration_0268.png
# Iteration 0269 visualization saved to gale_shapley_frames_new_layout/iteration_0269.png
# Iteration 0270 visualization saved to gale_shapley_frames_new_layout/iteration_0270.png
# Iteration 0271 visualization saved to gale_shapley_frames_new_layout/iteration_0271.png
# Iteration 0272 visualization saved to gale_shapley_frames_new_layout/iteration_0272.png
# Iteration 0273 visualization saved to gale_shapley_frames_new_layout/iteration_0273.png
# Iteration 0274 visualization saved to gale_shapley_frames_new_layout/iteration_0274.png
# Iteration 0275 visualization saved to gale_shapley_frames_new_layout/iteration_0275.png
# Iteration 0276 visualization saved to gale_shapley_frames_new_layout/iteration_0276.png
# Iteration 0277 visualization saved to gale_shapley_frames_new_layout/iteration_0277.png
# Iteration 0278 visualization saved to gale_shapley_frames_new_layout/iteration_0278.png
# Iteration 0279 visualization saved to gale_shapley_frames_new_layout/iteration_0279.png
# Iteration 0280 visualization saved to gale_shapley_frames_new_layout/iteration_0280.png
# Iteration 0281 visualization saved to gale_shapley_frames_new_layout/iteration_0281.png
# Iteration 0282 visualization saved to gale_shapley_frames_new_layout/iteration_0282.png
# Iteration 0283 visualization saved to gale_shapley_frames_new_layout/iteration_0283.png
# Iteration 0284 visualization saved to gale_shapley_frames_new_layout/iteration_0284.png
# Iteration 0285 visualization saved to gale_shapley_frames_new_layout/iteration_0285.png
# Iteration 0286 visualization saved to gale_shapley_frames_new_layout/iteration_0286.png
# Iteration 0287 visualization saved to gale_shapley_frames_new_layout/iteration_0287.png
# Iteration 0288 visualization saved to gale_shapley_frames_new_layout/iteration_0288.png
# Iteration 0289 visualization saved to gale_shapley_frames_new_layout/iteration_0289.png
# Iteration 0290 visualization saved to gale_shapley_frames_new_layout/iteration_0290.png
# Iteration 0291 visualization saved to gale_shapley_frames_new_layout/iteration_0291.png
# Iteration 0292 visualization saved to gale_shapley_frames_new_layout/iteration_0292.png
# Iteration 0293 visualization saved to gale_shapley_frames_new_layout/iteration_0293.png
# Iteration 0294 visualization saved to gale_shapley_frames_new_layout/iteration_0294.png
# Iteration 0295 visualization saved to gale_shapley_frames_new_layout/iteration_0295.png
# Iteration 0296 visualization saved to gale_shapley_frames_new_layout/iteration_0296.png
# Iteration 0297 visualization saved to gale_shapley_frames_new_layout/iteration_0297.png
# Iteration 0298 visualization saved to gale_shapley_frames_new_layout/iteration_0298.png
# Iteration 0299 visualization saved to gale_shapley_frames_new_layout/iteration_0299.png
# Iteration 0300 visualization saved to gale_shapley_frames_new_layout/iteration_0300.png
# Iteration 0301 visualization saved to gale_shapley_frames_new_layout/iteration_0301.png
# Iteration 0302 visualization saved to gale_shapley_frames_new_layout/iteration_0302.png
# Iteration 0303 visualization saved to gale_shapley_frames_new_layout/iteration_0303.png
# Iteration 0304 visualization saved to gale_shapley_frames_new_layout/iteration_0304.png
# Iteration 0305 visualization saved to gale_shapley_frames_new_layout/iteration_0305.png
# Iteration 0306 visualization saved to gale_shapley_frames_new_layout/iteration_0306.png
# Iteration 0307 visualization saved to gale_shapley_frames_new_layout/iteration_0307.png
# Iteration 0308 visualization saved to gale_shapley_frames_new_layout/iteration_0308.png
# Iteration 0309 visualization saved to gale_shapley_frames_new_layout/iteration_0309.png
# Iteration 0310 visualization saved to gale_shapley_frames_new_layout/iteration_0310.png
# Iteration 0311 visualization saved to gale_shapley_frames_new_layout/iteration_0311.png
# Iteration 0312 visualization saved to gale_shapley_frames_new_layout/iteration_0312.png
# Iteration 0313 visualization saved to gale_shapley_frames_new_layout/iteration_0313.png
# Iteration 0314 visualization saved to gale_shapley_frames_new_layout/iteration_0314.png
# Iteration 0315 visualization saved to gale_shapley_frames_new_layout/iteration_0315.png
# Iteration 0316 visualization saved to gale_shapley_frames_new_layout/iteration_0316.png
# Iteration 0317 visualization saved to gale_shapley_frames_new_layout/iteration_0317.png
# Iteration 0318 visualization saved to gale_shapley_frames_new_layout/iteration_0318.png
# Iteration 0319 visualization saved to gale_shapley_frames_new_layout/iteration_0319.png
# Iteration 0320 visualization saved to gale_shapley_frames_new_layout/iteration_0320.png
# Iteration 0321 visualization saved to gale_shapley_frames_new_layout/iteration_0321.png
# Iteration 0322 visualization saved to gale_shapley_frames_new_layout/iteration_0322.png
# Iteration 0323 visualization saved to gale_shapley_frames_new_layout/iteration_0323.png
# Iteration 0324 visualization saved to gale_shapley_frames_new_layout/iteration_0324.png
# Iteration 0325 visualization saved to gale_shapley_frames_new_layout/iteration_0325.png
# Iteration 0326 visualization saved to gale_shapley_frames_new_layout/iteration_0326.png
# Iteration 0327 visualization saved to gale_shapley_frames_new_layout/iteration_0327.png
# Iteration 0328 visualization saved to gale_shapley_frames_new_layout/iteration_0328.png
# Iteration 0329 visualization saved to gale_shapley_frames_new_layout/iteration_0329.png
# Iteration 0330 visualization saved to gale_shapley_frames_new_layout/iteration_0330.png
# Iteration 0331 visualization saved to gale_shapley_frames_new_layout/iteration_0331.png
# Iteration 0332 visualization saved to gale_shapley_frames_new_layout/iteration_0332.png
# Iteration 0333 visualization saved to gale_shapley_frames_new_layout/iteration_0333.png
# Iteration 0334 visualization saved to gale_shapley_frames_new_layout/iteration_0334.png
# Iteration 0335 visualization saved to gale_shapley_frames_new_layout/iteration_0335.png
# Iteration 0336 visualization saved to gale_shapley_frames_new_layout/iteration_0336.png
# Iteration 0337 visualization saved to gale_shapley_frames_new_layout/iteration_0337.png
# Iteration 0338 visualization saved to gale_shapley_frames_new_layout/iteration_0338.png
# Iteration 0339 visualization saved to gale_shapley_frames_new_layout/iteration_0339.png
# Iteration 0340 visualization saved to gale_shapley_frames_new_layout/iteration_0340.png
# Iteration 0341 visualization saved to gale_shapley_frames_new_layout/iteration_0341.png
# Iteration 0342 visualization saved to gale_shapley_frames_new_layout/iteration_0342.png
# Iteration 0343 visualization saved to gale_shapley_frames_new_layout/iteration_0343.png
# Iteration 0344 visualization saved to gale_shapley_frames_new_layout/iteration_0344.png
# Iteration 0345 visualization saved to gale_shapley_frames_new_layout/iteration_0345.png
# Iteration 0346 visualization saved to gale_shapley_frames_new_layout/iteration_0346.png
# Iteration 0347 visualization saved to gale_shapley_frames_new_layout/iteration_0347.png
# Iteration 0348 visualization saved to gale_shapley_frames_new_layout/iteration_0348.png
# Iteration 0349 visualization saved to gale_shapley_frames_new_layout/iteration_0349.png
# Iteration 0350 visualization saved to gale_shapley_frames_new_layout/iteration_0350.png
# Iteration 0351 visualization saved to gale_shapley_frames_new_layout/iteration_0351.png
# Iteration 0352 visualization saved to gale_shapley_frames_new_layout/iteration_0352.png
# Iteration 0353 visualization saved to gale_shapley_frames_new_layout/iteration_0353.png
# Iteration 0354 visualization saved to gale_shapley_frames_new_layout/iteration_0354.png
# Iteration 0355 visualization saved to gale_shapley_frames_new_layout/iteration_0355.png
# Iteration 0356 visualization saved to gale_shapley_frames_new_layout/iteration_0356.png
# Iteration 0357 visualization saved to gale_shapley_frames_new_layout/iteration_0357.png
# Iteration 0358 visualization saved to gale_shapley_frames_new_layout/iteration_0358.png
# Iteration 0359 visualization saved to gale_shapley_frames_new_layout/iteration_0359.png
# Iteration 0360 visualization saved to gale_shapley_frames_new_layout/iteration_0360.png
# Iteration 0361 visualization saved to gale_shapley_frames_new_layout/iteration_0361.png
# Iteration 0362 visualization saved to gale_shapley_frames_new_layout/iteration_0362.png
# Iteration 0363 visualization saved to gale_shapley_frames_new_layout/iteration_0363.png
# Iteration 0364 visualization saved to gale_shapley_frames_new_layout/iteration_0364.png
# Iteration 0365 visualization saved to gale_shapley_frames_new_layout/iteration_0365.png
# Iteration 0366 visualization saved to gale_shapley_frames_new_layout/iteration_0366.png
# Iteration 0367 visualization saved to gale_shapley_frames_new_layout/iteration_0367.png
# Iteration 0368 visualization saved to gale_shapley_frames_new_layout/iteration_0368.png
# Iteration 0369 visualization saved to gale_shapley_frames_new_layout/iteration_0369.png
# Iteration 0370 visualization saved to gale_shapley_frames_new_layout/iteration_0370.png
# Iteration 0371 visualization saved to gale_shapley_frames_new_layout/iteration_0371.png
# Iteration 0372 visualization saved to gale_shapley_frames_new_layout/iteration_0372.png
# Iteration 0373 visualization saved to gale_shapley_frames_new_layout/iteration_0373.png
# Iteration 0374 visualization saved to gale_shapley_frames_new_layout/iteration_0374.png
# Iteration 0375 visualization saved to gale_shapley_frames_new_layout/iteration_0375.png
# Iteration 0376 visualization saved to gale_shapley_frames_new_layout/iteration_0376.png
# Iteration 0377 visualization saved to gale_shapley_frames_new_layout/iteration_0377.png
# Iteration 0378 visualization saved to gale_shapley_frames_new_layout/iteration_0378.png
# Iteration 0379 visualization saved to gale_shapley_frames_new_layout/iteration_0379.png
# Iteration 0380 visualization saved to gale_shapley_frames_new_layout/iteration_0380.png
# Iteration 0381 visualization saved to gale_shapley_frames_new_layout/iteration_0381.png
# Iteration 0382 visualization saved to gale_shapley_frames_new_layout/iteration_0382.png
# Iteration 0383 visualization saved to gale_shapley_frames_new_layout/iteration_0383.png
# Iteration 0384 visualization saved to gale_shapley_frames_new_layout/iteration_0384.png
# Iteration 0385 visualization saved to gale_shapley_frames_new_layout/iteration_0385.png
# Iteration 0386 visualization saved to gale_shapley_frames_new_layout/iteration_0386.png
# Iteration 0387 visualization saved to gale_shapley_frames_new_layout/iteration_0387.png
# Iteration 0388 visualization saved to gale_shapley_frames_new_layout/iteration_0388.png
# Iteration 0389 visualization saved to gale_shapley_frames_new_layout/iteration_0389.png
# Iteration 0390 visualization saved to gale_shapley_frames_new_layout/iteration_0390.png
# Iteration 0391 visualization saved to gale_shapley_frames_new_layout/iteration_0391.png
# Iteration 0392 visualization saved to gale_shapley_frames_new_layout/iteration_0392.png
# Iteration 0393 visualization saved to gale_shapley_frames_new_layout/iteration_0393.png
# Iteration 0394 visualization saved to gale_shapley_frames_new_layout/iteration_0394.png
# Iteration 0395 visualization saved to gale_shapley_frames_new_layout/iteration_0395.png
# Iteration 0396 visualization saved to gale_shapley_frames_new_layout/iteration_0396.png
# Iteration 0397 visualization saved to gale_shapley_frames_new_layout/iteration_0397.png
# Iteration 0398 visualization saved to gale_shapley_frames_new_layout/iteration_0398.png
# Iteration 0399 visualization saved to gale_shapley_frames_new_layout/iteration_0399.png
# Iteration 0400 visualization saved to gale_shapley_frames_new_layout/iteration_0400.png
# Iteration 0401 visualization saved to gale_shapley_frames_new_layout/iteration_0401.png
# Iteration 0402 visualization saved to gale_shapley_frames_new_layout/iteration_0402.png
# Iteration 0403 visualization saved to gale_shapley_frames_new_layout/iteration_0403.png
# Iteration 0404 visualization saved to gale_shapley_frames_new_layout/iteration_0404.png
# Iteration 0405 visualization saved to gale_shapley_frames_new_layout/iteration_0405.png
# Iteration 0406 visualization saved to gale_shapley_frames_new_layout/iteration_0406.png
# Iteration 0407 visualization saved to gale_shapley_frames_new_layout/iteration_0407.png
# Iteration 0408 visualization saved to gale_shapley_frames_new_layout/iteration_0408.png
# Iteration 0409 visualization saved to gale_shapley_frames_new_layout/iteration_0409.png
# Iteration 0410 visualization saved to gale_shapley_frames_new_layout/iteration_0410.png
# Iteration 0411 visualization saved to gale_shapley_frames_new_layout/iteration_0411.png
# Iteration 0412 visualization saved to gale_shapley_frames_new_layout/iteration_0412.png
# Iteration 0413 visualization saved to gale_shapley_frames_new_layout/iteration_0413.png
# Iteration 0414 visualization saved to gale_shapley_frames_new_layout/iteration_0414.png
# Iteration 0415 visualization saved to gale_shapley_frames_new_layout/iteration_0415.png
# Iteration 0416 visualization saved to gale_shapley_frames_new_layout/iteration_0416.png
# Iteration 0417 visualization saved to gale_shapley_frames_new_layout/iteration_0417.png
# Iteration 0418 visualization saved to gale_shapley_frames_new_layout/iteration_0418.png
# Iteration 0419 visualization saved to gale_shapley_frames_new_layout/iteration_0419.png
# Iteration 0420 visualization saved to gale_shapley_frames_new_layout/iteration_0420.png
# Iteration 0421 visualization saved to gale_shapley_frames_new_layout/iteration_0421.png
# Iteration 0422 visualization saved to gale_shapley_frames_new_layout/iteration_0422.png
# Iteration 0423 visualization saved to gale_shapley_frames_new_layout/iteration_0423.png
# Iteration 0424 visualization saved to gale_shapley_frames_new_layout/iteration_0424.png
# Iteration 0425 visualization saved to gale_shapley_frames_new_layout/iteration_0425.png
# Iteration 0426 visualization saved to gale_shapley_frames_new_layout/iteration_0426.png
# Iteration 0427 visualization saved to gale_shapley_frames_new_layout/iteration_0427.png
# Iteration 0428 visualization saved to gale_shapley_frames_new_layout/iteration_0428.png
# Iteration 0429 visualization saved to gale_shapley_frames_new_layout/iteration_0429.png
# Iteration 0430 visualization saved to gale_shapley_frames_new_layout/iteration_0430.png
# Iteration 0431 visualization saved to gale_shapley_frames_new_layout/iteration_0431.png
# Iteration 0432 visualization saved to gale_shapley_frames_new_layout/iteration_0432.png
# Iteration 0433 visualization saved to gale_shapley_frames_new_layout/iteration_0433.png
# Iteration 0434 visualization saved to gale_shapley_frames_new_layout/iteration_0434.png
# Iteration 0435 visualization saved to gale_shapley_frames_new_layout/iteration_0435.png
# Iteration 0436 visualization saved to gale_shapley_frames_new_layout/iteration_0436.png
# Iteration 0437 visualization saved to gale_shapley_frames_new_layout/iteration_0437.png
# Iteration 0438 visualization saved to gale_shapley_frames_new_layout/iteration_0438.png
# Iteration 0439 visualization saved to gale_shapley_frames_new_layout/iteration_0439.png
# Iteration 0440 visualization saved to gale_shapley_frames_new_layout/iteration_0440.png
# Iteration 0441 visualization saved to gale_shapley_frames_new_layout/iteration_0441.png
# Iteration 0442 visualization saved to gale_shapley_frames_new_layout/iteration_0442.png
# Iteration 0443 visualization saved to gale_shapley_frames_new_layout/iteration_0443.png
# Iteration 0444 visualization saved to gale_shapley_frames_new_layout/iteration_0444.png
# Iteration 0445 visualization saved to gale_shapley_frames_new_layout/iteration_0445.png
# Iteration 0446 visualization saved to gale_shapley_frames_new_layout/iteration_0446.png
# Iteration 0447 visualization saved to gale_shapley_frames_new_layout/iteration_0447.png
# Iteration 0448 visualization saved to gale_shapley_frames_new_layout/iteration_0448.png
# Iteration 0449 visualization saved to gale_shapley_frames_new_layout/iteration_0449.png
# Iteration 0450 visualization saved to gale_shapley_frames_new_layout/iteration_0450.png
# Iteration 0451 visualization saved to gale_shapley_frames_new_layout/iteration_0451.png
# Iteration 0452 visualization saved to gale_shapley_frames_new_layout/iteration_0452.png
# Iteration 0453 visualization saved to gale_shapley_frames_new_layout/iteration_0453.png
# Iteration 0454 visualization saved to gale_shapley_frames_new_layout/iteration_0454.png
# Iteration 0455 visualization saved to gale_shapley_frames_new_layout/iteration_0455.png
# Iteration 0456 visualization saved to gale_shapley_frames_new_layout/iteration_0456.png
# Iteration 0457 visualization saved to gale_shapley_frames_new_layout/iteration_0457.png
# Iteration 0458 visualization saved to gale_shapley_frames_new_layout/iteration_0458.png
# Iteration 0459 visualization saved to gale_shapley_frames_new_layout/iteration_0459.png
# Iteration 0460 visualization saved to gale_shapley_frames_new_layout/iteration_0460.png
# Iteration 0461 visualization saved to gale_shapley_frames_new_layout/iteration_0461.png
# Iteration 0462 visualization saved to gale_shapley_frames_new_layout/iteration_0462.png
# Iteration 0463 visualization saved to gale_shapley_frames_new_layout/iteration_0463.png
# Iteration 0464 visualization saved to gale_shapley_frames_new_layout/iteration_0464.png
# Iteration 0465 visualization saved to gale_shapley_frames_new_layout/iteration_0465.png
# Iteration 0466 visualization saved to gale_shapley_frames_new_layout/iteration_0466.png
# Iteration 0467 visualization saved to gale_shapley_frames_new_layout/iteration_0467.png
# Iteration 0468 visualization saved to gale_shapley_frames_new_layout/iteration_0468.png
# Iteration 0469 visualization saved to gale_shapley_frames_new_layout/iteration_0469.png
# Iteration 0470 visualization saved to gale_shapley_frames_new_layout/iteration_0470.png
# Iteration 0471 visualization saved to gale_shapley_frames_new_layout/iteration_0471.png
# Iteration 0472 visualization saved to gale_shapley_frames_new_layout/iteration_0472.png
# Iteration 0473 visualization saved to gale_shapley_frames_new_layout/iteration_0473.png
# Iteration 0474 visualization saved to gale_shapley_frames_new_layout/iteration_0474.png
# Iteration 0475 visualization saved to gale_shapley_frames_new_layout/iteration_0475.png
# Iteration 0476 visualization saved to gale_shapley_frames_new_layout/iteration_0476.png
# Iteration 0477 visualization saved to gale_shapley_frames_new_layout/iteration_0477.png
# Iteration 0478 visualization saved to gale_shapley_frames_new_layout/iteration_0478.png
# Iteration 0479 visualization saved to gale_shapley_frames_new_layout/iteration_0479.png
# Iteration 0480 visualization saved to gale_shapley_frames_new_layout/iteration_0480.png
# Iteration 0481 visualization saved to gale_shapley_frames_new_layout/iteration_0481.png
# Iteration 0482 visualization saved to gale_shapley_frames_new_layout/iteration_0482.png
# Iteration 0483 visualization saved to gale_shapley_frames_new_layout/iteration_0483.png
# Iteration 0484 visualization saved to gale_shapley_frames_new_layout/iteration_0484.png
# Iteration 0485 visualization saved to gale_shapley_frames_new_layout/iteration_0485.png
# Iteration 0486 visualization saved to gale_shapley_frames_new_layout/iteration_0486.png
# Iteration 0487 visualization saved to gale_shapley_frames_new_layout/iteration_0487.png
# Iteration 0488 visualization saved to gale_shapley_frames_new_layout/iteration_0488.png
# Iteration 0489 visualization saved to gale_shapley_frames_new_layout/iteration_0489.png
# Iteration 0490 visualization saved to gale_shapley_frames_new_layout/iteration_0490.png
# Iteration 0491 visualization saved to gale_shapley_frames_new_layout/iteration_0491.png
# Iteration 0492 visualization saved to gale_shapley_frames_new_layout/iteration_0492.png
# Iteration 0493 visualization saved to gale_shapley_frames_new_layout/iteration_0493.png
# Iteration 0494 visualization saved to gale_shapley_frames_new_layout/iteration_0494.png
# Iteration 0495 visualization saved to gale_shapley_frames_new_layout/iteration_0495.png
# Iteration 0496 visualization saved to gale_shapley_frames_new_layout/iteration_0496.png
# Iteration 0497 visualization saved to gale_shapley_frames_new_layout/iteration_0497.png
# Iteration 0498 visualization saved to gale_shapley_frames_new_layout/iteration_0498.png
# Iteration 0499 visualization saved to gale_shapley_frames_new_layout/iteration_0499.png
# Iteration 0500 visualization saved to gale_shapley_frames_new_layout/iteration_0500.png
# Iteration 0501 visualization saved to gale_shapley_frames_new_layout/iteration_0501.png
# Iteration 0502 visualization saved to gale_shapley_frames_new_layout/iteration_0502.png
# Iteration 0503 visualization saved to gale_shapley_frames_new_layout/iteration_0503.png
# Finished generating 503 frames in 'gale_shapley_frames_new_layout' directory with new layout.

# %%
#Cria o GIF
import imageio.v2 as imageio
import glob

output_directory = 'gale_shapley_frames_new_layout'
image_files = sorted(glob.glob(os.path.join(output_directory, '*.png')))

gif_filename = 'gale_shapley_animation_new_layout.gif'

frame_duration = 0.5

print(f"Creating GIF animation from {len(image_files)} frames with new layout...")

with imageio.get_writer(gif_filename, mode='I', duration=frame_duration) as writer:
    for filename in image_files:
        image = imageio.imread(filename)
        writer.append_data(image)

print(f"GIF animation saved as '{gif_filename}'")
# Out:
# Creating GIF animation from 503 frames with new layout...
# GIF animation saved as 'gale_shapley_animation_new_layout.gif'
